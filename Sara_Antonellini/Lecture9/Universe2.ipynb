# %% [markdown]
# # Time to get your hands dirty! The transient Universe
#
# ## Task
# Let's go back to our previous example on the astrophysical transient.
# 8. Fit the same model from before with the same priors, but this time use nested sampling.
# $$
# y = b, \quad \text{for } t < t_0
# $$
#
# $$
# y = b + A \exp[-\alpha (t - t_0)], \quad \text{for } t \geq t_0
# $$
#
# Be careful with how you transform your parameter space into a unit hypercube for the nested sampling priors (I used ppf from scipy.stats.uniform, but there are other ways to do it)
# An appropriate check on whether you have done things correctly is that the posterior samples you get from the burst analysis here should give an equivalent corner plot to the MCMC you did earlier.
#
# 9. Another possible model that may explain the data is a Gaussian profile described by:
# $$
# y = b + A \exp[-(t - t_0)^2/2\sigma_g^2], \quad \text{for } t \geq t_0
# $$
# Fit this model usign nested sampling and reasonable priors (this time is up to you to decide...)
#
# 10. Unlike MCMCs, nested sampling provides the Bayesian evidence. Compute the Bayesian evidence for this Gaussian model, and for the original burst model. Which model is the favored description of the data? Express this in terms of the Jeffrey's scale.

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy import stats
import corner
import dynesty
from dynesty import plotting as dyplot

# %%
data=np.load("transient.npy")
time=data[:,0]# first column: time
flux = data[:, 1]  # second column: flux
error = data[:, 2]  # third column: uncertainties

# %%
plt.errorbar(time,flux, yerr=error,fmt='.', label='Data with uncertainties', ecolor='red', capsize=2)
plt.xlabel('Time (arbitrary units)')
plt.ylabel('Flux (arbitrary units)')
plt.legend()
plt.show()

# %%
def model(parameters):
    b, A, ln_alpha, t0 = parameters 
    t=time 
    y = np.zeros_like(t)
    for i in range(len(t)):
        if t[i] < t0:
            y[i] = b
        else:
            y[i] = b + A * np.exp(-np.exp(ln_alpha) * (t[i] - t0))
    return y

def loglikelihood(parameters):
    y_model = model(parameters)
    y_obs=flux
    sigma=error
    return -0.5 * np.sum(((y_obs - y_model) / sigma)**2 + np.log(2 * np.pi * sigma**2))

# %%
def prior(u):
    b = 50*u[0]  
    A = 50*u[1]    
    ln_alpha= 5*(2*u[2]-1)  
    t0 = 100*u[3]
    return [b,A,ln_alpha,t0]

# %%
ndim = 4 # Number of parameters in the model
sampler = dynesty.NestedSampler(loglikelihood, prior, ndim)
sampler.run_nested() # Run the nested sampling algorithm
sresults = sampler.results
# Out:
# 4206it [00:50, 17.19it/s, bound: 121 | nc: 17 | ncall: 109003 | eff(%):  3.859 | loglstar:   -inf < -175.166 <    inf | logz: -184.655 +/-  0.116 | dlogz: 32.966 >  0.509]  /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4217it [00:52, 11.60it/s, bound: 125 | nc: 26 | ncall: 112044 | eff(%):  3.764 | loglstar:   -inf < -174.890 <    inf | logz: -184.583 +/-  0.117 | dlogz: 32.873 >  0.509]/home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 7677it [01:11, 107.38it/s, +500 | bound: 179 | nc: 1 | ncall: 152647 | eff(%):  5.374 | loglstar:   -inf < -140.658 <    inf | logz: -155.227 +/-  0.168 | dlogz:  0.001 >  0.509]

# %%
rfig, raxes = dyplot.runplot(sresults)

# %%
labels = ["b","A", "ln_alpha", "t0"]
tfig, taxes = dyplot.traceplot(sresults, labels=labels)

# %%
cfig, caxes = dyplot.cornerplot(sresults, labels=labels)

# %%
def modelgauss(parameters):
    b, A, ln_sigma_g, t0 = parameters
    sigma_g = np.exp(ln_sigma_g)
    y = b + A * np.exp(-((time - t0)**2) / (2 * sigma_g**2))
    return y

def loglikelihoodgauss(parameters):
    y_model = modelgauss(parameters)
    y_obs=flux
    sigma=error
    return -0.5 * np.sum(((y_obs - y_model) / sigma)**2 + np.log(2 * np.pi * sigma**2))

def priorgauss(u):
    b = 50 * u[0]                         
    A = 50 * u[1]                        
    ln_sigma_g = 5*(2*u[2] - 1)          
    t0 = 100 * u[3]                        
    return [b, A, ln_sigma_g, t0]

# %%
ndim = 4

samplergauss = dynesty.NestedSampler(loglikelihoodgauss,priorgauss, ndim)
samplergauss.run_nested()
sresultsgauss = samplergauss.results
# Out:
# 3917it [00:23, 18.19it/s, bound: 54 | nc: 18 | ncall: 58398 | eff(%):  6.707 | loglstar:   -inf < -178.587 <    inf | logz: -185.283 +/-  0.108 | dlogz: 29.949 >  0.509]    /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3920it [00:23, 15.24it/s, bound: 55 | nc: 168 | ncall: 58645 | eff(%):  6.684 | loglstar:   -inf < -178.557 <    inf | logz: -185.281 +/-  0.108 | dlogz: 29.941 >  0.509]/home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3928it [00:28,  4.20it/s, bound: 65 | nc: 114 | ncall: 66809 | eff(%):  5.879 | loglstar:   -inf < -178.507 <    inf | logz: -185.275 +/-  0.108 | dlogz: 29.919 >  0.509] /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3930it [00:29,  3.48it/s, bound: 68 | nc: 1184 | ncall: 68648 | eff(%):  5.725 | loglstar:   -inf < -178.474 <    inf | logz: -185.274 +/-  0.108 | dlogz: 29.914 >  0.509]/home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 3932it [00:30,  2.65it/s, bound: 72 | nc: 2649 | ncall: 71768 | eff(%):  5.479 | loglstar:   -inf < -178.455 <    inf | logz: -185.273 +/-  0.108 | dlogz: 29.909 >  0.509]/home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4490it [00:43, 19.92it/s, bound: 116 | nc: 31 | ncall: 104431 | eff(%):  4.299 | loglstar:   -inf < -172.434 <    inf | logz: -182.918 +/-  0.132 | dlogz: 28.358 >  0.509] /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4507it [00:45, 13.65it/s, bound: 120 | nc: 431 | ncall: 107890 | eff(%):  4.177 | loglstar:   -inf < -172.270 <    inf | logz: -182.765 +/-  0.133 | dlogz: 28.172 >  0.509] /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4509it [00:46,  6.39it/s, bound: 124 | nc: 1644 | ncall: 110361 | eff(%):  4.086 | loglstar:   -inf < -172.242 <    inf | logz: -182.747 +/-  0.133 | dlogz: 28.150 >  0.509]/home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4545it [00:47, 28.98it/s, bound: 127 | nc: 12 | ncall: 113186 | eff(%):  4.016 | loglstar:   -inf < -171.889 <    inf | logz: -182.438 +/-  0.134 | dlogz: 27.768 >  0.509]  /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4622it [00:49, 56.88it/s, bound: 132 | nc: 94 | ncall: 116399 | eff(%):  3.971 | loglstar:   -inf < -171.219 <    inf | logz: -181.811 +/-  0.136 | dlogz: 26.986 >  0.509] /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4645it [00:50, 42.13it/s, bound: 134 | nc: 194 | ncall: 118317 | eff(%):  3.926 | loglstar:   -inf < -171.004 <    inf | logz: -181.632 +/-  0.136 | dlogz: 26.761 >  0.509]/home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4815it [00:52, 164.34it/s, bound: 140 | nc: 7 | ncall: 122951 | eff(%):  3.916 | loglstar:   -inf < -169.106 <    inf | logz: -180.210 +/-  0.140 | dlogz: 25.001 >  0.509] /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4867it [00:54, 64.27it/s, bound: 144 | nc: 1 | ncall: 125606 | eff(%):  3.875 | loglstar:   -inf < -168.640 <    inf | logz: -179.777 +/-  0.141 | dlogz: 24.464 >  0.509] /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4885it [00:57, 18.37it/s, bound: 157 | nc: 1942 | ncall: 135469 | eff(%):  3.606 | loglstar:   -inf < -168.408 <    inf | logz: -179.630 +/-  0.141 | dlogz: 24.281 >  0.509]/home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4898it [01:06,  5.89it/s, bound: 183 | nc: 412 | ncall: 154868 | eff(%):  3.163 | loglstar:   -inf < -168.323 <    inf | logz: -179.518 +/-  0.141 | dlogz: 24.143 >  0.509] /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4907it [01:14,  3.69it/s, bound: 205 | nc: 665 | ncall: 171786 | eff(%):  2.856 | loglstar:   -inf < -168.264 <    inf | logz: -179.446 +/-  0.141 | dlogz: 24.052 >  0.509]/home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4914it [01:16,  3.79it/s, bound: 211 | nc: 1575 | ncall: 175598 | eff(%):  2.798 | loglstar:   -inf < -168.218 <    inf | logz: -179.391 +/-  0.141 | dlogz: 23.983 >  0.509]/home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4919it [01:21,  2.71it/s, bound: 227 | nc: 512 | ncall: 188316 | eff(%):  2.612 | loglstar:   -inf < -168.166 <    inf | logz: -179.352 +/-  0.141 | dlogz: 23.934 >  0.509] /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4923it [01:29,  1.75it/s, bound: 250 | nc: 2876 | ncall: 205284 | eff(%):  2.398 | loglstar:   -inf < -168.130 <    inf | logz: -179.321 +/-  0.141 | dlogz: 23.895 >  0.509]/home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4926it [01:32,  1.57it/s, bound: 257 | nc: 1638 | ncall: 210239 | eff(%):  2.343 | loglstar:   -inf < -168.112 <    inf | logz: -179.298 +/-  0.141 | dlogz: 23.866 >  0.509]/home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4929it [01:36,  1.39it/s, bound: 265 | nc: 6104 | ncall: 216434 | eff(%):  2.277 | loglstar:   -inf < -168.076 <    inf | logz: -179.275 +/-  0.141 | dlogz: 23.837 >  0.509]/home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4931it [01:40,  1.13it/s, bound: 278 | nc: 5569 | ncall: 226201 | eff(%):  2.180 | loglstar:   -inf < -168.057 <    inf | logz: -179.260 +/-  0.141 | dlogz: 23.818 >  0.509]/home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4932it [01:41,  1.10it/s, bound: 282 | nc: 2779 | ncall: 228980 | eff(%):  2.154 | loglstar:   -inf < -168.046 <    inf | logz: -179.252 +/-  0.141 | dlogz: 23.808 >  0.509]/home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4934it [01:43,  1.10it/s, bound: 289 | nc: 131 | ncall: 234105 | eff(%):  2.108 | loglstar:   -inf < -167.990 <    inf | logz: -179.236 +/-  0.142 | dlogz: 23.788 >  0.509] /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4937it [01:45,  1.23it/s, bound: 296 | nc: 5207 | ncall: 239832 | eff(%):  2.059 | loglstar:   -inf < -167.948 <    inf | logz: -179.212 +/-  0.142 | dlogz: 23.758 >  0.509]/home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4938it [01:47,  1.01s/it, bound: 304 | nc: 5610 | ncall: 245442 | eff(%):  2.012 | loglstar:   -inf < -167.934 <    inf | logz: -179.204 +/-  0.142 | dlogz: 23.748 >  0.509]/home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4941it [01:50,  1.07it/s, bound: 314 | nc: 1602 | ncall: 253069 | eff(%):  1.952 | loglstar:   -inf < -167.877 <    inf | logz: -179.179 +/-  0.142 | dlogz: 23.718 >  0.509]/home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 4973it [01:52, 16.09it/s, bound: 319 | nc: 14 | ncall: 257177 | eff(%):  1.934 | loglstar:   -inf < -167.611 <    inf | logz: -178.921 +/-  0.142 | dlogz: 23.395 >  0.509]  /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 5121it [01:54, 141.13it/s, bound: 325 | nc: 23 | ncall: 261803 | eff(%):  1.956 | loglstar:   -inf < -166.247 <    inf | logz: -177.806 +/-  0.144 | dlogz: 21.984 >  0.509]/home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# /home/sara/myenv/lib/python3.10/site-packages/dynesty/bounding.py:617: UserWarning: The enlargement factor for the ellipsoidal bounds determined from bootstrapping is very large. If you are using uniform sampling that may mean that the sampling will be inefficient. This may be caused by a very complex posterior shape. You may consider using more livepoints or different sampler (i.e. rslice or rwalk) or alternatively disable bootstrap (bootstrap=0)
#   warnings.warn(
# 8484it [02:00, 70.42it/s, +500 | bound: 349 | nc: 1 | ncall: 280264 | eff(%):  3.211 | loglstar:   -inf < -144.313 <    inf | logz: -160.548 +/-  0.180 | dlogz:  0.001 >  0.509]

# %%
rfig, raxes = dyplot.runplot(sresultsgauss)

# %%
labels = ["b","A", "ln_sigma_g", "t0"]
tfig, taxes = dyplot.traceplot(sresultsgauss, labels=labels)

# %%
cfig, caxes = dyplot.cornerplot(sresultsgauss, labels=labels)

# %%
Bburst = np.exp(sresults.logz[-1])
Bgauss = np.exp(sresultsgauss.logz[-1])
BF = Bgauss/Bburst
lnBF = sresultsgauss.logz[-1] - sresults.logz[-1]

# Interpretazione secondo Jeffreys scale
if lnBF < 0:
    interpretazione = "Negative (supports burst model)"
elif lnBF < 1.1:
    interpretazione = "Barely worth mentioning"
elif lnBF < 2.3:
    interpretazione = "Substantial evidence for Gaussian"
elif lnBF < 3.4:
    interpretazione = "Strong evidence for Gaussian"
elif lnBF < 4.6:
    interpretazione = "Very strong evidence for Gaussian"
else:
    interpretazione = "Decisive evidence for Gaussian"

print(f"Bayes Factor (Gauss vs Burst): {BF}")
print(f"Interpretazione secondo Jeffreys: {interpretazione}")
# Out:
# Bayes Factor (Gauss vs Burst): 0.004885450943679627
# Interpretazione secondo Jeffreys: Negative (supports burst model)
